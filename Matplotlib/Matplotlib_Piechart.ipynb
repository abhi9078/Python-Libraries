# %%
"""@Author: Abhilash Meher
 @Date: 18-11-2022 1:25PM @Last Modified by: Abhilash Meher
  @Last Modified time: 18-11-2022 04:00PM @Title : Matplotlib Problems
"""
# Out:
# '@Author: Abhilash Meher\n @Date: 18-11-2022 1:25PM @Last Modified by: Abhilash Meher\n  @Last Modified time: 18-11-2022 02:00PM @Title : Matplotlib Problems\n'

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Write a Python programming to create a pie chart of the popularity of programming
# Languages.

# %%
programming_lan = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
fig, ax = plt.subplots()
plt.pie(popularity, labels=programming_lan)
fig.set_facecolor('white')

# %% [markdown]
# 2. Write a Python programming to create a pie chart with a title of the popularity of programming
# Languages.

# %%
programming_lan = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
fig, ax = plt.subplots()
plt.pie(popularity, labels=programming_lan, autopct='%.2f%%')
fig.set_facecolor('white')
plt.title("Popularity of Programming Language")
# Out:
# Text(0.5, 1.0, 'Popularity of Programming Language')

# %% [markdown]
# 3. Write a Python programming to create a pie chart of gold medal achievements of five most
# successful countries in 2016 Summer Olympics. Read the data from a csv file.

# %%
import pandas as pd
df =  pd.read_csv('medal.csv')
country_data = df["country"]
medal_data = df["gold_medal"]
explode = (0.1, 0, 0, 0, 0)  
plt.pie(medal_data, labels=country_data, explode=explode, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Gold medal achievements of five most successful\n"+"countries in 2016 Summer Olympics")
plt.show()
