# %%
"""@Author: Abhilash Meher
 @Date: 19-11-2022 12:25PM @Last Modified by: Abhilash Meher
  @Last Modified time: 19-11-2022 01:00PM @Title : Seaborn Problems
"""
# Out:
# '@Author: Abhilash Meher\n @Date: 19-11-2022 12:25PM @Last Modified by: Abhilash Meher\n  @Last Modified time: 19-11-2022 01:00PM @Title : Seaborn Problems\n'

# %% [markdown]
# 1. Write a program to draw bar plot of sex against survived for a dataset given in the url.

# %%
import seaborn as sns
import pandas as pd

titanic= pd.read_csv('titanic.csv')
sns.barplot(x = titanic["sex"], y = titanic["survived"])
# Out:
# <AxesSubplot: xlabel='sex', ylabel='survived'>
